# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_data.csv')
df.head(10)
# Out:
#    Unnamed: 0  UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  \
# 0           0    420825             50578       58400  89.55         67
# 1           1    537409             47145       65550  73.23         67
# 2           2    417566             53278       61360  89.63         67
# 3           3    624493             57513       66113  88.48         67
# 4           4    539055             52378       60300  88.39         67
# 5           5    518279             54513       61900  89.66         67
# 6           6    529269             46349       61500  76.42         67
# 7           7    510278             43894       61900  71.89         67
# 8           8    490213             53713       61973  89.56         67
# 9           9    510980             52603       61300  86.95         67
#
#    SUPPLIER_ID  MANUFACTURER_ID  CURRENT_PINCODE_ID EMPLOYMENT_TYPE  ...  \
# 0        22807               45                1441        Salaried  ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV',
#        'BRANCH_ID', 'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID',
#        'EMPLOYMENT_TYPE', 'STATE_ID', 'EMPLOYEE_CODE_ID', 'MOBILENO_AVL_FLAG',
#        'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG',
#        'PASSPORT_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION',
#        'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS',
#        'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT', 'PRI_DISBURSED_AMOUNT',
#        'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS', 'SEC_OVERDUE_ACCTS',
#        'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT', 'SEC_DISBURSED_AMOUNT',
#        'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT', 'NEW_ACCTS_IN_LAST_SIX_MONTHS',
#        'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'AVERAGE_ACCT_AGE',
#        'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES', 'LOAN_DEFAULT', 'AGE',
#        'LOAN_AGE'],
#       dtype='object')

# %%
df.shape
# Out:
# (233154, 42)

# %%
df.dtypes
# Out:
# Unnamed: 0                               int64
# UNIQUEID                                 int64
# DISBURSED_AMOUNT                         int64
# ASSET_COST                               int64
# LTV                                    float64
# BRANCH_ID                                int64
# SUPPLIER_ID                              int64
# MANUFACTURER_ID                          int64
# CURRENT_PINCODE_ID                       int64
# EMPLOYMENT_TYPE                         object
# STATE_ID                                 int64
# EMPLOYEE_CODE_ID                         int64
# MOBILENO_AVL_FLAG                        int64
# AADHAR_FLAG                              int64
# PAN_FLAG                                 int64
# VOTERID_FLAG                             int64
# DRIVING_FLAG                             int64
# PASSPORT_FLAG                            int64
# PERFORM_CNS_SCORE                        int64
# PERFORM_CNS_SCORE_DESCRIPTION           object
# ...

# %%
df['SUPPLIER_ID']= df['SUPPLIER_ID'].astype(object)
df['UNIQUEID']= df['UNIQUEID'].astype(object)
df['BRANCH_ID']= df['BRANCH_ID'].astype(object)
df['MANUFACTURER_ID']= df['MANUFACTURER_ID'].astype(object)
df['CURRENT_PINCODE_ID']= df['CURRENT_PINCODE_ID'].astype(object)
df['STATE_ID']= df['STATE_ID'].astype(object)
df['EMPLOYEE_CODE_ID']= df['EMPLOYEE_CODE_ID'].astype(object)
df['MOBILENO_AVL_FLAG']= df['MOBILENO_AVL_FLAG'].astype('category')
df['AADHAR_FLAG']= df['AADHAR_FLAG'].astype('category')
df['PAN_FLAG']= df['PAN_FLAG'].astype('category')
df['VOTERID_FLAG']= df['VOTERID_FLAG'].astype('category')
df['DRIVING_FLAG']= df['DRIVING_FLAG'].astype('category')
df['PASSPORT_FLAG']= df['PASSPORT_FLAG'].astype('category')
df['NEW_ACCTS_IN_LAST_SIX_MONTHS']= df['NEW_ACCTS_IN_LAST_SIX_MONTHS'].astype('category')
df['DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS']= df['DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS'].astype('category')
df['NO_OF_INQUIRIES']= df['NO_OF_INQUIRIES'].astype('category')
df['PRI_NO_OF_ACCTS']= df['PRI_NO_OF_ACCTS'].astype('category')
df['SEC_NO_OF_ACCTS']= df['SEC_NO_OF_ACCTS'].astype('category')
df['PRI_ACTIVE_ACCTS']= df['PRI_ACTIVE_ACCTS'].astype('category')
df['SEC_ACTIVE_ACCTS']= df['SEC_ACTIVE_ACCTS'].astype('category')
df['SEC_ACTIVE_ACCTS']= df['SEC_ACTIVE_ACCTS'].astype('category')
df['PRI_OVERDUE_ACCTS']= df['PRI_OVERDUE_ACCTS'].astype('category')
df['SEC_OVERDUE_ACCTS']= df['SEC_OVERDUE_ACCTS'].astype('category')
df['LOAN_AGE']=df['LOAN_AGE'].astype('category')
df['LOAN_DEFAULT']=df['LOAN_DEFAULT'].astype('category')

# %%
dfn = df.select_dtypes(np.number)
dfn.head()
# Out:
#    Unnamed: 0  DISBURSED_AMOUNT  ASSET_COST    LTV  PERFORM_CNS_SCORE  \
# 0           0             50578       58400  89.55                  0
# 1           1             47145       65550  73.23                598
# 2           2             53278       61360  89.63                  0
# 3           3             57513       66113  88.48                305
# 4           4             52378       60300  88.39                  0
#
#    PRI_CURRENT_BALANCE  PRI_SANCTIONED_AMOUNT  PRI_DISBURSED_AMOUNT  \
# 0                    0                      0                     0
# 1                27600                  50200                 50200
# 2                    0                      0                     0
# 3                    0                      0                     0
# 4                    0                      0                     0
#
#    SEC_CURRENT_BALANCE  SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for x in dfn.columns:
    plt.figure(figsize = (12,1))
    sns.boxplot(x= dfn[x])
    plt.show()

# %%
from sklearn.preprocessing import RobustScaler
robsc = RobustScaler()
df1 = pd.DataFrame(robsc.fit_transform(dfn),columns = dfn.columns)

# %%
numrobsc = df1.copy()

# %%
df1.head()
# Out:
#    Unnamed: 0  DISBURSED_AMOUNT  ASSET_COST       LTV  EMPLOYMENT_TYPE  \
# 0   -1.000000         -0.243066   -0.930384  0.862069             -1.0
# 1   -0.999991         -0.501809   -0.400156 -0.241379              0.0
# 2   -0.999983         -0.039569   -0.710877  0.867478              0.0
# 3   -0.999974          0.279620   -0.358405  0.789723              0.0
# 4   -0.999966         -0.107401   -0.789484  0.783638              0.0
#
#    PERFORM_CNS_SCORE  PERFORM_CNS_SCORE_DESCRIPTION  PRI_CURRENT_BALANCE  \
# 0           0.000000                       0.000000             0.000000
# 1           0.882006                       0.867928             0.788425
# 2           0.000000                       0.000000             0.000000
# 3           0.449853                       1.031659             0.000000
# 4           0.000000                       0.000000             0.000000
#
#    PRI_SANCTIONED_AMOUNT  PRI_DISBURSED_AMOUNT  SEC_CURRENT_BALANCE  \
# ...

# %%
for x in df1.columns:
    plt.figure(figsize = (12,1))
    sns.boxplot(x= df1[x])
    plt.show()

# %%
for x in df1.columns:
    plt.figure(figsize = (12,1))
    sns.kdeplot(df1[x])
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV',
#        'BRANCH_ID', 'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID',
#        'EMPLOYMENT_TYPE', 'STATE_ID', 'EMPLOYEE_CODE_ID', 'MOBILENO_AVL_FLAG',
#        'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG',
#        'PASSPORT_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION',
#        'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS',
#        'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT', 'PRI_DISBURSED_AMOUNT',
#        'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS', 'SEC_OVERDUE_ACCTS',
#        'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT', 'SEC_DISBURSED_AMOUNT',
#        'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT', 'NEW_ACCTS_IN_LAST_SIX_MONTHS',
#        'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'AVERAGE_ACCT_AGE',
#        'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES', 'LOAN_DEFAULT', 'AGE',
#        'LOAN_AGE'],
#       dtype='object')

# %%
vari = df[['MOBILENO_AVL_FLAG',
       'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG',
       'PASSPORT_FLAG','PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS',
       'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS', 'SEC_OVERDUE_ACCTS','NEW_ACCTS_IN_LAST_SIX_MONTHS',
       'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
       'NO_OF_INQUIRIES']]

# %%
for i in vari.columns:
    vari[i]= df[i].replace(df[i].value_counts(normalize = True))
# Out:
# <ipython-input-54-cfd5d0e07d44>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vari[i]= df[i].replace(df[i].value_counts(normalize = True))

# %%
vari.head()
# Out:
#    MOBILENO_AVL_FLAG  AADHAR_FLAG  PAN_FLAG  VOTERID_FLAG  DRIVING_FLAG  \
# 0                1.0      0.84032  0.924423      0.855057      0.976758
# 1                1.0      0.84032  0.924423      0.855057      0.976758
# 2                1.0      0.84032  0.924423      0.855057      0.976758
# 3                1.0      0.84032  0.924423      0.855057      0.976758
# 4                1.0      0.84032  0.924423      0.855057      0.976758
#
#    PASSPORT_FLAG  PRI_NO_OF_ACCTS  PRI_ACTIVE_ACCTS  PRI_OVERDUE_ACCTS  \
# 0       0.997873         0.501600          0.587663           0.887306
# 1       0.997873         0.150021          0.180374           0.085652
# 2       0.997873         0.501600          0.587663           0.887306
# 3       0.997873         0.055821          0.587663           0.887306
# 4       0.997873         0.501600          0.587663           0.887306
#
#    SEC_NO_OF_ACCTS  SEC_ACTIVE_ACCTS  SEC_OVERDUE_ACCTS  \
# ...

# %%
df5=df[['BRANCH_ID','SUPPLIER_ID','MANUFACTURER_ID','CURRENT_PINCODE_ID','STATE_ID',
           'EMPLOYEE_CODE_ID']]

# %%
for i in df5.columns:
    df5[i]= df5[i].replace(df5[i].value_counts(normalize = True))
# Out:
# <ipython-input-57-2a9bfe1c4db3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5[i]= df5[i].replace(df5[i].value_counts(normalize = True))

# %%
df5.head()
# Out:
#    BRANCH_ID  SUPPLIER_ID  MANUFACTURER_ID  CURRENT_PINCODE_ID  STATE_ID  \
# 0   0.048586     0.000236          0.24287            0.000077  0.143703
# 1   0.048586     0.000236          0.24287            0.000030  0.143703
# 2   0.048586     0.000236          0.24287            0.000202  0.143703
# 3   0.048586     0.000236          0.24287            0.000064  0.143703
# 4   0.048586     0.000236          0.24287            0.000060  0.143703
#
#    EMPLOYEE_CODE_ID
# 0          0.000232
# 1          0.000232
# 2          0.000232
# 3          0.000232
# 4          0.000232

# %%
df5.isnull().sum()
# Out:
# BRANCH_ID             0
# SUPPLIER_ID           0
# MANUFACTURER_ID       0
# CURRENT_PINCODE_ID    0
# STATE_ID              0
# EMPLOYEE_CODE_ID      0
# dtype: int64

# %%
varncth = df2.copy()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm = MinMaxScaler()
dfa = pd.DataFrame(mm.fit_transform(dfn),columns = dfn.columns)
dfa.head()
# Out:
#    Unnamed: 0  DISBURSED_AMOUNT  ASSET_COST       LTV  PERFORM_CNS_SCORE  \
# 0    0.000000          0.038125    0.013442  0.935860           0.000000
# 1    0.000004          0.034612    0.017934  0.743792           0.671910
# 2    0.000009          0.040888    0.015302  0.936801           0.000000
# 3    0.000013          0.045222    0.018287  0.923267           0.342697
# 4    0.000017          0.039967    0.014636  0.922208           0.000000
#
#    PRI_CURRENT_BALANCE  PRI_SANCTIONED_AMOUNT  PRI_DISBURSED_AMOUNT  \
# 0             0.064710                0.00000               0.00000
# 1             0.064978                0.00005               0.00005
# 2             0.064710                0.00000               0.00000
# 3             0.064710                0.00000               0.00000
# 4             0.064710                0.00000               0.00000
#
#    SEC_CURRENT_BALANCE  SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  \
# ...

# %%
for i in dfa.columns:
    plt.figure(figsize = (12,1))
    sns.boxplot(x = dfa[i])
    plt.show()

# %%
df['LOAN_DEFAULT']=df['LOAN_DEFAULT'].astype('int')

# %%
means = df.groupby('EMPLOYMENT_TYPE')['LOAN_DEFAULT'].mean()

# %%
means
# Out:
# EMPLOYMENT_TYPE
# Not Known        0.214593
# Salaried         0.203458
# Self employed    0.227657
# Name: LOAN_DEFAULT, dtype: float64

# %%
df['EMPLOYMENT_TYPE']=df['EMPLOYMENT_TYPE'].map(means)

# %%
df['EMPLOYMENT_TYPE']
# Out:
# 0         0.203458
# 1         0.227657
# 2         0.227657
# 3         0.227657
# 4         0.227657
#             ...
# 233149    0.203458
# 233150    0.227657
# 233151    0.203458
# 233152    0.203458
# 233153    0.203458
# Name: EMPLOYMENT_TYPE, Length: 233154, dtype: float64

# %%
df['PERFORM_CNS_SCORE_DESCRIPTION'].nunique()
# Out:
# 20

# %%
mean2 = df.groupby('PERFORM_CNS_SCORE_DESCRIPTION')['LOAN_DEFAULT'].mean()

# %%
df['PERFORM_CNS_SCORE_DESCRIPTION'] = df['PERFORM_CNS_SCORE_DESCRIPTION'].map(mean2)

# %%
pd.set_option('max_columns',None)

# %%
df.head()
# Out:
#    Unnamed: 0 UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV BRANCH_ID  \
# 0           0   420825             50578       58400  89.55        67
# 1           1   537409             47145       65550  73.23        67
# 2           2   417566             53278       61360  89.63        67
# 3           3   624493             57513       66113  88.48        67
# 4           4   539055             52378       60300  88.39        67
#
#   SUPPLIER_ID MANUFACTURER_ID CURRENT_PINCODE_ID  EMPLOYMENT_TYPE STATE_ID  \
# 0       22807              45               1441         0.203458        6
# 1       22807              45               1502         0.227657        6
# 2       22807              45               1497         0.227657        6
# 3       22807              45               1501         0.227657        6
# 4       22807              45               1495         0.227657        6
#
#   EMPLOYEE_CODE_ID MOBILENO_AVL_FLAG AADHAR_FLAG PAN_FLAG VOTERID_FLAG  \
# ...

# %%
df['PERFORM_CNS_SCORE_DESCRIPTION']
# Out:
# 0         0.231313
# 1         0.272629
# 2         0.231313
# 3         0.280423
# 4         0.231313
#             ...
# 233149    0.149586
# 233150    0.165746
# 233151    0.231313
# 233152    0.231313
# 233153    0.231313
# Name: PERFORM_CNS_SCORE_DESCRIPTION, Length: 233154, dtype: float64

# %%
df3 = df[['PERFORM_CNS_SCORE_DESCRIPTION','EMPLOYMENT_TYPE']]

# %%
catg = df3.copy()

# %%
catg.head()
# Out:
#    PERFORM_CNS_SCORE_DESCRIPTION  EMPLOYMENT_TYPE
# 0                       0.231313         0.203458
# 1                       0.272629         0.227657
# 2                       0.231313         0.227657
# 3                       0.280423         0.227657
# 4                       0.231313         0.227657

# %%
dft = df[['LOAN_DEFAULT']]
dft.head()
# Out:
#    LOAN_DEFAULT
# 0             0
# 1             1
# 2             0
# 3             1
# 4             1

# %%
df3.head()
# Out:
#    PERFORM_CNS_SCORE_DESCRIPTION  EMPLOYMENT_TYPE
# 0                       0.231313         0.203458
# 1                       0.272629         0.227657
# 2                       0.231313         0.227657
# 3                       0.280423         0.227657
# 4                       0.231313         0.227657

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV',
#        'BRANCH_ID', 'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID',
#        'EMPLOYMENT_TYPE', 'STATE_ID', 'EMPLOYEE_CODE_ID', 'MOBILENO_AVL_FLAG',
#        'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG',
#        'PASSPORT_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION',
#        'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS',
#        'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT', 'PRI_DISBURSED_AMOUNT',
#        'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS', 'SEC_OVERDUE_ACCTS',
#        'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT', 'SEC_DISBURSED_AMOUNT',
#        'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT', 'NEW_ACCTS_IN_LAST_SIX_MONTHS',
#        'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'AVERAGE_ACCT_AGE',
#        'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES', 'LOAN_DEFAULT', 'AGE',
#        'LOAN_AGE'],
#       dtype='object')

# %%
final = pd.concat([dfa,vari,catg,df5,dft],axis = 1)

# %%
final.head()
# Out:
#    Unnamed: 0  DISBURSED_AMOUNT  ASSET_COST       LTV  PERFORM_CNS_SCORE  \
# 0    0.000000          0.038125    0.013442  0.935860           0.000000
# 1    0.000004          0.034612    0.017934  0.743792           0.671910
# 2    0.000009          0.040888    0.015302  0.936801           0.000000
# 3    0.000013          0.045222    0.018287  0.923267           0.342697
# 4    0.000017          0.039967    0.014636  0.922208           0.000000
#
#    PRI_CURRENT_BALANCE  PRI_SANCTIONED_AMOUNT  PRI_DISBURSED_AMOUNT  \
# 0             0.064710                0.00000               0.00000
# 1             0.064978                0.00005               0.00005
# 2             0.064710                0.00000               0.00000
# 3             0.064710                0.00000               0.00000
# 4             0.064710                0.00000               0.00000
#
#    SEC_CURRENT_BALANCE  SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  \
# ...

# %%
final.columns
# Out:
# Index(['Unnamed: 0', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV',
#        'PERFORM_CNS_SCORE', 'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT',
#        'PRI_DISBURSED_AMOUNT', 'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT',
#        'SEC_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT',
#        'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'AGE', 'MOBILENO_AVL_FLAG',
#        'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG',
#        'PASSPORT_FLAG', 'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS',
#        'PRI_OVERDUE_ACCTS', 'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS',
#        'SEC_OVERDUE_ACCTS', 'NEW_ACCTS_IN_LAST_SIX_MONTHS',
#        'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'NO_OF_INQUIRIES',
#        'PERFORM_CNS_SCORE_DESCRIPTION', 'EMPLOYMENT_TYPE', 'BRANCH_ID',
#        'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'STATE_ID',
#        'EMPLOYEE_CODE_ID', 'LOAN_DEFAULT'],
#       dtype='object')

# %%
final.shape
# Out:
# (233154, 40)

# %%
final.isnull().sum()
# Out:
# Unnamed: 0                             0
# DISBURSED_AMOUNT                       0
# ASSET_COST                             0
# LTV                                    0
# PERFORM_CNS_SCORE                      0
# PRI_CURRENT_BALANCE                    0
# PRI_SANCTIONED_AMOUNT                  0
# PRI_DISBURSED_AMOUNT                   0
# SEC_CURRENT_BALANCE                    0
# SEC_SANCTIONED_AMOUNT                  0
# SEC_DISBURSED_AMOUNT                   0
# PRIMARY_INSTAL_AMT                     0
# SEC_INSTAL_AMT                         0
# AVERAGE_ACCT_AGE                       0
# CREDIT_HISTORY_LENGTH                  0
# AGE                                    0
# MOBILENO_AVL_FLAG                      0
# AADHAR_FLAG                            0
# PAN_FLAG                               0
# VOTERID_FLAG                           0
# DRIVING_FLAG                           0
# PASSPORT_FLAG                          0
# PRI_NO_OF_ACCTS                        0
# ...

# %%
final.to_csv('finaldata.csv')

# %%
a = pd.read_csv('finaldata.csv')

# %%
a = pd.read_csv('finaldata.csv')

# %%
a.shape
# Out:
# (233154, 41)

# %%
a.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV',
#        'PERFORM_CNS_SCORE', 'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT',
#        'PRI_DISBURSED_AMOUNT', 'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT',
#        'SEC_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT',
#        'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'AGE', 'MOBILENO_AVL_FLAG',
#        'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG',
#        'PASSPORT_FLAG', 'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS',
#        'PRI_OVERDUE_ACCTS', 'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS',
#        'SEC_OVERDUE_ACCTS', 'NEW_ACCTS_IN_LAST_SIX_MONTHS',
#        'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'NO_OF_INQUIRIES',
#        'PERFORM_CNS_SCORE_DESCRIPTION', 'EMPLOYMENT_TYPE', 'BRANCH_ID',
#        'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'STATE_ID',
#        'EMPLOYEE_CODE_ID', 'LOAN_DEFAULT'],
#       dtype='object')

# %%
a = a.drop(['Unnamed: 0','Unnamed: 0.1'],axis = 1)

# %%
a.head(3)
# Out:
#    DISBURSED_AMOUNT  ASSET_COST       LTV  PERFORM_CNS_SCORE  \
# 0          0.038125    0.013442  0.935860            0.00000
# 1          0.034612    0.017934  0.743792            0.67191
# 2          0.040888    0.015302  0.936801            0.00000
#
#    PRI_CURRENT_BALANCE  PRI_SANCTIONED_AMOUNT  PRI_DISBURSED_AMOUNT  \
# 0             0.064710                0.00000               0.00000
# 1             0.064978                0.00005               0.00005
# 2             0.064710                0.00000               0.00000
#
#    SEC_CURRENT_BALANCE  SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  ...  \
# 0             0.015698                    0.0                   0.0  ...
# 1             0.015698                    0.0                   0.0  ...
# 2             0.015698                    0.0                   0.0  ...
#
#    NO_OF_INQUIRIES  PERFORM_CNS_SCORE_DESCRIPTION  EMPLOYMENT_TYPE  BRANCH_ID  \
# ...

# %%
a.shape
# Out:
# (233154, 39)

# %%
a.dtypes
# Out:
# DISBURSED_AMOUNT                       float64
# ASSET_COST                             float64
# LTV                                    float64
# PERFORM_CNS_SCORE                      float64
# PRI_CURRENT_BALANCE                    float64
# PRI_SANCTIONED_AMOUNT                  float64
# PRI_DISBURSED_AMOUNT                   float64
# SEC_CURRENT_BALANCE                    float64
# SEC_SANCTIONED_AMOUNT                  float64
# SEC_DISBURSED_AMOUNT                   float64
# PRIMARY_INSTAL_AMT                     float64
# SEC_INSTAL_AMT                         float64
# AVERAGE_ACCT_AGE                       float64
# CREDIT_HISTORY_LENGTH                  float64
# AGE                                    float64
# MOBILENO_AVL_FLAG                      float64
# AADHAR_FLAG                            float64
# PAN_FLAG                               float64
# VOTERID_FLAG                           float64
# DRIVING_FLAG                           float64
# ...

# %%
plt.figure(figsize = (40,40))
sns.heatmap(a.corr(method = 'pearson'),annot = True)
plt.show()

# %%
a = a.drop(['MOBILENO_AVL_FLAG'],axis = 1)

# %%
a.shape
# Out:
# (233154, 43)

# %%
plt.figure(figsize = (40,40))
sns.heatmap(a.corr(method = 'pearson'),annot = True)
plt.show()

# %%
a['LOAN_DEFAULT']=a['LOAN_DEFAULT'].astype('category')

# %%
fig,ax = plt.subplots(figsize = (40,40))
sns.heatmap(a.corr(method = 'pearson'),annot = True,cmap = 'Blues',vmin =0.9,vmax = 1.65,
           linewidth = 0.3,cbar_kws = {'shrink':1})
plt.show()

# %%
fig,ax = plt.subplots(figsize = (40,40))
mask = np.triu(np.ones_like(a.corr(method = 'pearson'),dtype = np.bool))
mask = mask[1:,:-1]
cmap = sns.diverging_palette(0,230,90,60, as_cmap = True)
corr = a.corr(method = 'pearson').iloc[1:,:-1].copy()
sns.heatmap(corr,mask = mask,annot = True, fmt = '.2f',linewidths = 3,
           cmap = cmap,vmin = -1,vmax=1,cbar_kws = {'shrink':1},square = True)
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0],labels = yticks, rotation = 0)
plt.xticks(plt.xticks()[0],labels = xticks)
title = 'CORRELATION MATRIX\nSAMPLED CEREALS COMPOSITION\n'
plt.title(title,loc='left',fontsize=18)
plt.show()

# %%
sns.pairplot(a,hue = 'LOAN_DEFAULT')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-52d6e081923b> in <module>
# ----> 1 sns.pairplot(a,hue = 'LOAN_DEFAULT')
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
a.columns
# Out:
# Index(['DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'PERFORM_CNS_SCORE',
#        'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT', 'PRI_DISBURSED_AMOUNT',
#        'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT', 'SEC_DISBURSED_AMOUNT',
#        'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT', 'AVERAGE_ACCT_AGE',
#        'CREDIT_HISTORY_LENGTH', 'AGE', 'MOBILENO_AVL_FLAG', 'AADHAR_FLAG',
#        'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG', 'PASSPORT_FLAG',
#        'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS',
#        'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS', 'SEC_OVERDUE_ACCTS',
#        'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
#        'NO_OF_INQUIRIES', 'PERFORM_CNS_SCORE_DESCRIPTION', 'EMPLOYMENT_TYPE',
#        'BRANCH_ID', 'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID',
#        'STATE_ID', 'EMPLOYEE_CODE_ID', 'LOAN_DEFAULT'],
#       dtype='object')

# %%
b = a[['DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'PERFORM_CNS_SCORE',
       'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT', 'PRI_DISBURSED_AMOUNT',
       'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT', 'SEC_DISBURSED_AMOUNT',
       'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT', 'AVERAGE_ACCT_AGE',
       'CREDIT_HISTORY_LENGTH','AGE','PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS', 'PRI_OVERDUE_ACCTS',
       'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS', 'SEC_OVERDUE_ACCTS',
       'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
       'NO_OF_INQUIRIES', 'PERFORM_CNS_SCORE_DESCRIPTION', 'EMPLOYMENT_TYPE','LOAN_DEFAULT']]

# %%
sns.pairplot(b,hue = 'LOAN_DEFAULT')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-b0429bf584ab> in <module>
# ----> 1 sns.pairplot(b,hue = 'LOAN_DEFAULT')
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1962     elif diag_kind == "kde":
#    1963         diag_kws.setdefault("fill", True)
# -> 1964         grid.map_diag(kdeplot, **diag_kws)
#    1965
#    1966     # Maybe plot on the off-diagonals
#
# ...
